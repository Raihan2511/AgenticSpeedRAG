# %%
import pandas as pd
from datasets import load_dataset
import tqdm

# %%
import pandas as pd

csv_path = r"c:\Users\raiha\Downloads\amazon fashion\Amazon Fashion.csv"

df = pd.read_csv(csv_path)
df = df[["name", "image"]]

# preview
print(df.head())

# save
df.to_csv(
    r"C:\Users\raiha\OneDrive\Desktop\AgenticSpeedRAG\data\filtered_dataset.csv",
    index=False
)
# Out:
#                                                 name  \
# 0  Aqualogica Glow+ Dewy Sunscreen SPF 50 PA+++ F...
# 1  MARVIK Soft Silicone Adjustable Band Strap Com...
# 2  108 Panchatantra Stories for Children (Illustr...
# 3  Black and White and Blue: Adult Cinema From th...
# 4  SAFARI 15 Ltrs Sea Blue Casual/School/College ...
#
#                                                image
# 0  https://m.media-amazon.com/images/I/51TSC6Uogx...
# 1  https://m.media-amazon.com/images/I/51vYDop04S...
# 2  https://m.media-amazon.com/images/I/81VJ+MAc7Y...
# 3  https://m.media-amazon.com/images/I/51RIhaW3t1...
# 4  https://m.media-amazon.com/images/I/61kmCas5OC...
